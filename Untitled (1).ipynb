# %% [markdown]
# 1.Explain the key features of python that make it popular choice for programming
#
# Ans: 1.python is a programming language that is easy to understand and write, making it a popular choice among developers and programmers.
# 2.python is compatible with various programming paradigms such as procedural , object -oriented and functional programming .
#
#
# 2.Describe the role  of predefined keywords in python and provide examples of how they are used in a program.
#
# Ans:The  predefined words in python that have special meaning and can't used as identifiers .
#
# Example: if ,else,while ,for ,def,class, import, export, true, false etc
#
# Keywords are case sensitive and can't be redefine within a python program
#
#
# 3 .Compare and contrast mutable and immutable objects in python with example.
#
# Ans :In python  the mutable object can be changed after creation but the immutable objects cannot be changed
#
# Example of mutable:
# List: we can modify a list by changing elements
#
# my_list =[10,20,30]
# my_list[1]=200
# The list will become [10,200,30]
#
# Example of mutable:
#
# Tuple: we can not change tuple after its creation.
# my_tuple=(10,20,30)
# my_tuple[1]=10
# This will be an error and can't change.
#
#
# 4.Discuss the different types of operators in python and provide examples of how they are uses.
#
# Ans: There are four types of operators
# a.Arithmetic  operator
# b.Comparison operator
# c .Logical operator
# d. Assignment operator
#
# Example:
# a.Arithmetic operator:
# Suppose
# a=10
# b=4
# Addition(+): a+b
# Result:14
# Subtraction(-): a-b
# Result:6
# Multiplication(*):a*b
# Result:40
# Division(/):a/b
# Result :2.5
#
# b.Comparison operator:
#
# Equal to (==):10==10
# Result:True
#
# Not equal (!=):10!=5
# Result: true
# Greater than (>):10>5
# Result:true
# Less than (<):10<5
# Result:false
# c.logical operator
# and: True and False
# Result:False
# Or: True or false
# Result: True
#
# d.assignment operator:
# Simple assignment (=):a=10
# Add and assign (+=):a+=20
# Equivalent to (a=a+20)
#
# Etc
#
#
# 5.Explain the concept of type casting in python with examples.
#
# Ans: Type casting also referred to as type conversion , is the process of changing one data type to another in python . python provides built in function of type casting such as int (),str(),float(),list(), tuple () etc
#  it's often necessary for performing arithmetic operations,data manipulation and imputation operations in python.
#  Example:
#  String to integer:
#  a=2
#  Print (type(a))
#  Print type (int(a))
#
#  Integer to float:
#  x=42
#  Print(type (x))
#  y=float(x)
#  Type(y)
#
#  Float to interger:
#  b=6.78
#  Type(b)
#  Int(b)
#  Type(int(n))
#
#  Etc
#
#
#  6.How do conditional statements work in python? Illustratate with examples
#
#  Ans: Conditional statements are used to excute code based on evaluation of one or more conditions.
#  Example: If ,elif  and else
#
#  If statement: The if statement evaluates a condition.If the condition is true,the code with of statement runs.if the condition is fale the code block is skipped.
#
#  Elif statment: the elif statement provides additional conditions to evaluate if the preceding if condition was false.It allows for multiple conditions to be checked in sequence.
#
#  Else statement: The else statement provides a default code block that runs if none of the preceding if ot elif are true. It handles cases where no conditions have been worked.
#
#
#
#  7.Describe the different types of loops in python and their use cases with examples
#
#  Ans :
#  There are two primary types of loops
#  1.while loops
#  2.for  loops
#
#  Use of loops
#
#
#  1.while loops:  while loops are used to repeated execute a block of code as long as a specific condition remains true .
#  Suppose :
#  n=8
#  i=1
#  While i<n
#  Print (I)
#  i+1
#
#  Result:
#  1 2 3 4 5 6 7
#
#
#  2.For loops:For loops are used for interating over a sequence of elements.
#  Example: sequence of elements such as list ,tuple, string..
